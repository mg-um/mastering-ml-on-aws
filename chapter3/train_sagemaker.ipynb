# %%
% matplotlib inline

# %%
# Download train.csv from https://www.kaggle.com/c/boston-housing/

# %%
import pandas as pd

from os.path import expanduser

SRC_PATH = expanduser("~") + '/SageMaker/mastering-ml-on-aws/chapter3/'

# %%
housing_df = pd.read_csv(SRC_PATH + 'train.csv')
housing_df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
training_features = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
label = 'medv'

# %%
from sklearn.model_selection import train_test_split

housing_df_reordered = housing_df[[label] + training_features]
training_df, test_df = train_test_split(housing_df_reordered, test_size=0.2)
training_df.head()
# Out:
#      medv     crim    zn  indus  chas    nox     rm   age     dis  tax  \
# 17   14.8  0.95577   0.0   8.14     0  0.538  6.047  88.8  4.4534  307
# 149  23.3  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121  276
# 104  17.0  1.41385   0.0  19.58     1  0.871  6.129  96.0  1.7494  403
# 168  24.3  0.33983  22.0   5.86     0  0.431  6.108  34.9  8.0555  330
# 223  20.6  0.03306   0.0   5.19     0  0.515  6.059  37.3  4.8122  224
#
#      ptratio  lstat
# 17      21.0  17.28
# 149     16.4  13.51
# 104     14.7  15.12
# 168     19.1   9.16
# 223     20.2   8.51

# %%
training_df.reindex().to_csv('training-housing.csv', header=False, index=False)
test_df[training_features].reindex().to_csv('testing-housing.csv', header=False, index=False)

# %%
import sagemaker
from sagemaker import get_execution_role
import json
import boto3

sess = sagemaker.Session()
role = get_execution_role()

bucket = "mastering-ml-aws"
prefix = "chapter3/linearmodels"

train_path = prefix + '/train'
validation_path = prefix + '/validation'

sess.upload_data(path='training-housing.csv', bucket=bucket, key_prefix=train_path)
sess.upload_data(path='testing-housing.csv', bucket=bucket, key_prefix=validation_path)

s3_train_data = 's3://{}/{}'.format(bucket, train_path)
s3_validation_data = 's3://{}/{}'.format(bucket, validation_path)

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')
s3_output_location = 's3://{}/{}/output'.format(bucket, prefix)

# %%
import boto3
import sagemaker
from sagemaker.session import s3_input

sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=s3_output_location,
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=len(training_features),
                           predictor_type='regressor',
                           mini_batch_size=1)

linear.fit({'train': s3_input(s3_train_data, content_type='text/csv'), \
            'test': s3_input(s3_validation_data, content_type='text/csv')})
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-01-04-00-02-36-561
# 2019-01-04 00:02:36 Starting - Starting the training job...
# 2019-01-04 00:02:38 Starting - Launching requested ML instances......
# 2019-01-04 00:03:47 Starting - Preparing the instances for training...............
# 2019-01-04 00:06:28 Downloading - Downloading input data..
# Docker entrypoint called with argument(s): train
# [01/04/2019 00:06:48 INFO 139972492891968] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/04/2019 00:06:48 INFO 139972492891968] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'11', u'mini_batch_size': u'1', u'predictor_type': u'regressor'}
# [01/04/2019 00:06:48 INFO 139972492891968] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'11', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/04/2019 00:06:48 WARNING 139972492891968] Loggers have already been setup.
# Process 1 is a worker.
# [01/04/2019 00:06:48 INFO 139972492891968] Using default worker.
# [01/04/2019 00:06:48 INFO 139972492891968] Create Store: local
# [01/04/2019 00:06:49 INFO 139972492891968] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f
"Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.848907}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.4349159294727549, "sum": 0.4349159294727549, "min": 0.4349159294727549}}, "EndTime": 1546560485.848974, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.848959}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.4604505611682811, "sum": 0.4604505611682811, "min": 0.4604505611682811}}, "EndTime": 1546560485.849025, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849011}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.43491834597153867, "sum": 0.43491834597153867, "min": 0.43491834597153867}}, "EndTime": 1546560485.849078, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849063}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.4604513791688946, "sum": 0.4604513791688946, "min": 0.4604513791688946}}, "EndTime": 1546560485.849129, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849115}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.4521463363786412, "sum": 0.4521463363786412, "min": 0.4521463363786412}}, "EndTime": 1546560485.849181, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849166}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8496112979294772, "sum": 0.8496112979294772, "min": 0.8496112979294772}}, "EndTime": 1546560485.849231, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849217}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.4521465637656005, "sum": 0.4521465637656005, "min": 0.4521465637656005}}, "EndTime": 1546560485.849279, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849265}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8496106599177625, "sum": 0.8496106599177625, "min": 0.8496106599177625}}, "EndTime": 1546560485.849318, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849305}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9577352847467336, "sum": 0.9577352847467336, "min": 0.9577352847467336}}, "EndTime": 1546560485.849398, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849382}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9790606830589357, "sum": 0.9790606830589357, "min": 0.9790606830589357}}, "EndTime": 1546560485.849451, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849438}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9577437864605887, "sum": 0.9577437864605887, "min": 0.9577437864605887}}, "EndTime": 1546560485.849501, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849488}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9790601185520796, "sum": 0.9790601185520796, "min": 0.9790601185520796}}, "EndTime": 1546560485.84955, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849536}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9701408727006683, "sum": 0.9701408727006683, "min": 0.9701408727006683}}, "EndTime": 1546560485.849607, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849592}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.237984215989116, "sum": 1.237984215989116, "min": 1.237984215989116}}, "EndTime": 1546560485.849648, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849635}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9701409987373779, "sum": 0.9701409987373779, "min": 0.9701409987373779}}, "EndTime": 1546560485.849691, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849678}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2379808325402926, "sum": 1.2379808325402926, "min": 1.2379808325402926}}, "EndTime": 1546560485.849742, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560485.849728}
#
# [01/04/2019 00:08:05 INFO 139972492891968] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.336498904321
# [01/04/2019 00:08:05 INFO 139972492891968] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.335870689071
# [01/04/2019 00:08:05 INFO 139972492891968] Epoch 14: Loss improved. Updating best model
# [01/04/2019 00:08:05 INFO 139972492891968] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 266, "sum": 266.0, "min": 266}, "Number of Batches Since Last Reset": {"count": 1, "max": 266, "sum": 266.0, "min": 266}, "Number of Records Since Last Reset": {"count": 1, "max": 266, "sum": 266.0, "min": 266}, "Total Batches Seen": {"count": 1, "max": 4257, "sum": 4257.0, "min": 4257}, "Total Records Seen": {"count": 1, "max": 4257, "sum": 4257.0, "min": 4257}, "Max Records Seen Between Resets": {"count": 1, "max": 266, "sum": 266.0, "min": 266}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1546560485.852822, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1546560480.705065}
#
# [01/04/2019 00:08:05 INFO 139972492891968] #throughput_metric: host=algo-1, train throughput=51.671676391 records/second
# [01/04/2019 00:08:05 WARNING 139972492891968] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/04/2019 00:08:05 WARNING 139972492891968] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/04/2019 00:08:06 INFO 139972492891968] #train_score (algo-1) : ('mse_objective', 25.568373011868822)
# [01/04/2019 00:08:06 INFO 139972492891968] #quality_metric: host=algo-1, train mse_objective <loss>=25.5683730119
# [01/04/2019 00:08:06 INFO 139972492891968] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [01/04/2019 00:08:06 INFO 139972492891968] Saved checkpoint to "/tmp/tmpzCa5ZN/mx-mod-0000.params"
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1546560486.308721, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1546560486.307709}
#
# [01/04/2019 00:08:06 ERROR 139972492891968] Customer Error: Rows 1-1 in file /opt/ml/input/data/test/testing-housing.csv have different fields than the expected size 12.
# 2019-01-04 00:08:15 Failed - Training job failed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-05a2375feb3d> in <module>()
#      15                            mini_batch_size=1)
#      16
# ---> 17 linear.fit({'train': s3_input(s3_train_data, content_type='text/csv'),             'test': s3_input(s3_validation_data, content_type='text/csv')})
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name)
#     232         self.latest_training_job = _TrainingJob.start_new(self, inputs)
#     233         if wait:
# --> 234             self.latest_training_job.wait(logs=logs)
#     235
#     236     def _compilation_job_name(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#     571     def wait(self, logs=True):
#     572         if logs:
# --> 573             self.sagemaker_session.logs_for_job(self.job_name, wait=True)
#     574         else:
#     575             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll)
#    1126
#    1127         if wait:
# -> 1128             self._check_job_status(job_name, description, 'TrainingJobStatus')
#    1129             if dot:
#    1130                 print()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#     826             reason = desc.get('FailureReason', '(No reason provided)')
#     827             job_type = status_key_name.replace('JobStatus', ' job')
# --> 828             raise ValueError('Error for {} {}: {} Reason: {}'.format(job_type, job, status, reason))
#     829
#     830     def wait_for_endpoint(self, endpoint, poll=5):
#
# ValueError: Error for Training job linear-learner-2019-01-04-00-02-36-561: Failed Reason: ClientError: Rows 1-1 in file /opt/ml/input/data/test/testing-housing.csv have different fields than the expected size 12.

# %%
transformer = linear.transformer(instance_count=1, instance_type='ml.m4.xlarge', output_path=s3_output_location)
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2019-01-04-00-02-36-561

# %%
transformer.transform(s3_validation_data, content_type='text/csv')
# Out:
# INFO:sagemaker:Creating transform job with name: linear-learner-2019-01-04-00-09-38-808

# %%
transformer.wait()
# Out:
# ..........................................!

# %%
transformer.output_path
# Out:
# 's3://mastering-ml-aws/chapter3/linearmodels/output'

# %%
# !aws s3 cp s3://mastering-ml-aws/chapter3/linearmodels/output/testing-housing.csv.out - | head
# Out:
# {"score":18.911674499511719}
# {"score":41.916255950927734}
# {"score":20.833599090576172}
# {"score":38.696208953857422}
# {"score":30.833646774291992}
# {"score":19.361166000366211}
# {"score":24.461696624755859}
# {"score":24.615261077880859}
# {"score":4.382085800170898}
# {"score":25.914594650268555}

# %%
s3 = boto3.resource('s3')
s3.Bucket(bucket).download_file('chapter3/linearmodels/output/testing-housing.csv.out', 'testing-housing.csv.out')

# %%
predictions = pd.read_json('testing-housing.csv.out',lines=True)
predictions.head()
# Out:
#        score
# 0  18.911674
# 1  41.916256
# 2  20.833599
# 3  38.696209
# 4  30.833647

# %%
evaluation_df = pd.DataFrame({'actual':list(test_df[label]),'predicted':list(predictions['score'])})
evaluation_df.head()
# Out:
#    actual  predicted
# 0    14.3  18.911674
# 1    50.0  41.916256
# 2    23.2  20.833599
# 3    46.0  38.696209
# 4    30.8  30.833647

# %%
from sklearn.metrics import r2_score

r2_score(evaluation_df['actual'], evaluation_df['predicted'])
# Out:
# 0.7962794586033369
