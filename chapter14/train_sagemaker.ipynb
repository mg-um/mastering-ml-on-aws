# %%
import boto3
import sagemaker
from sagemaker import get_execution_role

sess = sagemaker.Session()
role = get_execution_role()
container = sagemaker.amazon.amazon_estimator.get_image_uri('us-east-1', "xgboost", "latest")

s3_validation_data = 's3://mastering-ml-aws/chapter4/test-vector-csv/'
s3_train_data = 's3://mastering-ml-aws/chapter4/training-vector-csv/'
s3_output_location = 's3://mastering-ml-aws/chapter14/output/'

# %%
sagemaker_model = sagemaker.estimator.Estimator(container,
                                                role,
                                                train_instance_count=1,
                                                train_instance_type='ml.c4.4xlarge',
                                                train_volume_size=30,
                                                train_max_run=360000,
                                                input_mode='File',
                                                output_path=s3_output_location,
                                                sagemaker_session=sess)

# %%
sagemaker_model.set_hyperparameters(objective='binary:logistic',
                                    max_depth=5,
                                    eta=0.2,
                                    gamma=4,
                                    min_child_weight=6,
                                    subsample=0.7,
                                    silent=0,
                                    num_round=50)

# %%
from sagemaker.tuner import HyperparameterTuner, ContinuousParameter,IntegerParameter

tree_tuner = HyperparameterTuner(estimator=sagemaker_model, 
                                 objective_metric_name='validation:auc',
                                 max_jobs=10,
                                 max_parallel_jobs=3,
                                 hyperparameter_ranges={'lambda': ContinuousParameter(0, 1000),
                                                       'max_depth': IntegerParameter(3,7),
                                                       'eta':ContinuousParameter(0.1, 0.5)})

train_data = sagemaker.session.s3_input(s3_train_data, distribution='FullyReplicated',
                                        content_type='text/csv', s3_data_type='S3Prefix')

validation_data = sagemaker.session.s3_input(s3_validation_data, distribution='FullyReplicated',
                                             content_type='text/csv', s3_data_type='S3Prefix')

data_channels = {'train': train_data, 'validation': validation_data}

tree_tuner.fit(inputs=data_channels, logs=True)
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: xgboost-190407-1342

# %%
tree_tuner.best_training_job()
# Out:
# 'xgboost-190407-1342-001-5c7e2a26'

# %%
sess.sagemaker_client.describe_training_job(TrainingJobName=tree_tuner.best_training_job())
# Out:
# {'TrainingJobName': 'xgboost-190407-1342-001-5c7e2a26',
#  'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:095585830284:training-job/xgboost-190407-1342-001-5c7e2a26',
#  'TuningJobArn': 'arn:aws:sagemaker:us-east-1:095585830284:hyper-parameter-tuning-job/xgboost-190407-1342',
#  'ModelArtifacts': {'S3ModelArtifacts': 's3://mastering-ml-aws/chapter4/sagemaker/output/xgboost-190407-1342-001-5c7e2a26/output/model.tar.gz'},
#  'TrainingJobStatus': 'Completed',
#  'SecondaryStatus': 'Completed',
#  'HyperParameters': {'_tuning_objective_metric': 'validation:auc',
#   'eta': '0.4843166334129595',
#   'gamma': '4',
#   'lambda': '892.5118136129357',
#   'max_depth': '7',
#   'min_child_weight': '6',
#   'num_round': '50',
#   'objective': 'binary:logistic',
#   'silent': '0',
#   'subsample': '0.7'},
#  'AlgorithmSpecification': {'TrainingImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
#   'TrainingInputMode': 'File',
#   'MetricDefinitions': [{'Name': 'train:mae',
#     'Regex': '.*\\[[0-9]+\\]#011train-mae:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:auc',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-auc:(\\S+)'},
#    {'Name': 'train:merror',
#     'Regex': '.*\\[[0-9]+\\]#011train-merror:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'train:auc',
#     'Regex': '.*\\[[0-9]+\\]#011train-auc:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:mae',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-mae:(\\S+)'},
#    {'Name': 'validation:error',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-error:(\\S+)'},
#    {'Name': 'validation:merror',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-merror:(\\S+)'},
#    {'Name': 'validation:logloss',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-logloss:(\\S+)'},
#    {'Name': 'train:rmse',
#     'Regex': '.*\\[[0-9]+\\]#011train-rmse:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'train:logloss',
#     'Regex': '.*\\[[0-9]+\\]#011train-logloss:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'train:mlogloss',
#     'Regex': '.*\\[[0-9]+\\]#011train-mlogloss:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:rmse',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-rmse:(\\S+)'},
#    {'Name': 'validation:ndcg',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-ndcg:(\\S+)'},
#    {'Name': 'train:error',
#     'Regex': '.*\\[[0-9]+\\]#011train-error:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:mlogloss',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-mlogloss:(\\S+)'},
#    {'Name': 'train:ndcg',
#     'Regex': '.*\\[[0-9]+\\]#011train-ndcg:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'train:map',
#     'Regex': '.*\\[[0-9]+\\]#011train-map:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:map',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-map:(\\S+)'}]},
#  'RoleArn': 'arn:aws:iam::095585830284:role/service-role/AmazonSageMaker-ExecutionRole-20181129T145112',
#  'InputDataConfig': [{'ChannelName': 'train',
#    'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#      'S3Uri': 's3://mastering-ml-aws/chapter4/training-vector-csv/',
#      'S3DataDistributionType': 'FullyReplicated'}},
#    'ContentType': 'text/csv',
#    'CompressionType': 'None',
#    'RecordWrapperType': 'None'},
#   {'ChannelName': 'validation',
#    'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#      'S3Uri': 's3://mastering-ml-aws/chapter4/test-vector-csv/',
#      'S3DataDistributionType': 'FullyReplicated'}},
#    'ContentType': 'text/csv',
#    'CompressionType': 'None',
#    'RecordWrapperType': 'None'}],
#  'OutputDataConfig': {'KmsKeyId': '',
#   'S3OutputPath': 's3://mastering-ml-aws/chapter4/sagemaker/output'},
#  'ResourceConfig': {'InstanceType': 'ml.c4.4xlarge',
#   'InstanceCount': 1,
#   'VolumeSizeInGB': 30},
#  'StoppingCondition': {'MaxRuntimeInSeconds': 360000},
#  'CreationTime': datetime.datetime(2019, 4, 7, 13, 42, 54, 820000, tzinfo=tzlocal()),
#  'TrainingStartTime': datetime.datetime(2019, 4, 7, 13, 45, 30, 696000, tzinfo=tzlocal()),
#  'TrainingEndTime': datetime.datetime(2019, 4, 7, 13, 48, 4, 715000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2019, 4, 7, 13, 48, 4, 715000, tzinfo=tzlocal()),
#  'SecondaryStatusTransitions': [{'Status': 'Starting',
#    'StartTime': datetime.datetime(2019, 4, 7, 13, 42, 54, 820000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 13, 45, 30, 696000, tzinfo=tzlocal()),
#    'StatusMessage': 'Preparing the instances for training'},
#   {'Status': 'Downloading',
#    'StartTime': datetime.datetime(2019, 4, 7, 13, 45, 30, 696000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 13, 45, 53, 704000, tzinfo=tzlocal()),
#    'StatusMessage': 'Downloading input data'},
#   {'Status': 'Training',
#    'StartTime': datetime.datetime(2019, 4, 7, 13, 45, 53, 704000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 13, 47, 58, 69000, tzinfo=tzlocal()),
#    'StatusMessage': 'Training image download completed. Training in progress.'},
#   {'Status': 'Uploading',
#    'StartTime': datetime.datetime(2019, 4, 7, 13, 47, 58, 69000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 13, 48, 4, 715000, tzinfo=tzlocal()),
#    'StatusMessage': 'Uploading generated training model'},
#   {'Status': 'Completed',
#    'StartTime': datetime.datetime(2019, 4, 7, 13, 48, 4, 715000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 13, 48, 4, 715000, tzinfo=tzlocal()),
#    'StatusMessage': 'Training job completed'}],
#  'FinalMetricDataList': [{'MetricName': 'validation:auc',
#    'Value': 0.653240978717804,
#    'Timestamp': datetime.datetime(1970, 1, 18, 23, 50, 44, 873000, tzinfo=tzlocal())},
#   {'MetricName': 'train:auc',
#    'Value': 0.6529290080070496,
#    'Timestamp': datetime.datetime(1970, 1, 18, 23, 50, 44, 873000, tzinfo=tzlocal())}],
#  'EnableNetworkIsolation': False,
#  'EnableInterContainerTrafficEncryption': False,
#  'ResponseMetadata': {'RequestId': 'f8e40804-a515-41fb-a969-26c374519fed',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f8e40804-a515-41fb-a969-26c374519fed',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4688',
#    'date': 'Sun, 07 Apr 2019 14:56:03 GMT'},
#   'RetryAttempts': 0}}

# %%
sess.sagemaker_client.describe_hyper_parameter_tuning_job(HyperParameterTuningJobName='xgboost-190407-1342')
# Out:
# {'HyperParameterTuningJobName': 'xgboost-190407-1342',
#  'HyperParameterTuningJobArn': 'arn:aws:sagemaker:us-east-1:095585830284:hyper-parameter-tuning-job/xgboost-190407-1342',
#  'HyperParameterTuningJobConfig': {'Strategy': 'Bayesian',
#   'HyperParameterTuningJobObjective': {'Type': 'Maximize',
#    'MetricName': 'validation:auc'},
#   'ResourceLimits': {'MaxNumberOfTrainingJobs': 10,
#    'MaxParallelTrainingJobs': 3},
#   'ParameterRanges': {'IntegerParameterRanges': [{'Name': 'max_depth',
#      'MinValue': '3',
#      'MaxValue': '7',
#      'ScalingType': 'Auto'}],
#    'ContinuousParameterRanges': [{'Name': 'lambda',
#      'MinValue': '0',
#      'MaxValue': '1000',
#      'ScalingType': 'Auto'},
#     {'Name': 'eta',
#      'MinValue': '0.1',
#      'MaxValue': '0.5',
#      'ScalingType': 'Auto'}],
#    'CategoricalParameterRanges': []},
#   'TrainingJobEarlyStoppingType': 'Off'},
#  'TrainingJobDefinition': {'StaticHyperParameters': {'_tuning_objective_metric': 'validation:auc',
#    'gamma': '4',
#    'min_child_weight': '6',
#    'num_round': '50',
#    'objective': 'binary:logistic',
#    'silent': '0',
#    'subsample': '0.7'},
#   'AlgorithmSpecification': {'TrainingImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
#    'TrainingInputMode': 'File',
#    'MetricDefinitions': [{'Name': 'train:mae',
#      'Regex': '.*\\[[0-9]+\\]#011train-mae:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:auc',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-auc:(\\S+)'},
#     {'Name': 'train:merror',
#      'Regex': '.*\\[[0-9]+\\]#011train-merror:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'train:auc',
#      'Regex': '.*\\[[0-9]+\\]#011train-auc:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:mae',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-mae:(\\S+)'},
#     {'Name': 'validation:error',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-error:(\\S+)'},
#     {'Name': 'validation:merror',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-merror:(\\S+)'},
#     {'Name': 'validation:logloss',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-logloss:(\\S+)'},
#     {'Name': 'train:rmse',
#      'Regex': '.*\\[[0-9]+\\]#011train-rmse:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'train:logloss',
#      'Regex': '.*\\[[0-9]+\\]#011train-logloss:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'train:mlogloss',
#      'Regex': '.*\\[[0-9]+\\]#011train-mlogloss:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:rmse',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-rmse:(\\S+)'},
#     {'Name': 'validation:ndcg',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-ndcg:(\\S+)'},
#     {'Name': 'train:error',
#      'Regex': '.*\\[[0-9]+\\]#011train-error:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:mlogloss',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-mlogloss:(\\S+)'},
#     {'Name': 'train:ndcg',
#      'Regex': '.*\\[[0-9]+\\]#011train-ndcg:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'train:map',
#      'Regex': '.*\\[[0-9]+\\]#011train-map:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:map',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-map:(\\S+)'}]},
#   'RoleArn': 'arn:aws:iam::095585830284:role/service-role/AmazonSageMaker-ExecutionRole-20181129T145112',
#   'InputDataConfig': [{'ChannelName': 'train',
#     'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#       'S3Uri': 's3://mastering-ml-aws/chapter4/training-vector-csv/',
#       'S3DataDistributionType': 'FullyReplicated'}},
#     'ContentType': 'text/csv'},
#    {'ChannelName': 'validation',
#     'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#       'S3Uri': 's3://mastering-ml-aws/chapter4/test-vector-csv/',
#       'S3DataDistributionType': 'FullyReplicated'}},
#     'ContentType': 'text/csv'}],
#   'OutputDataConfig': {'S3OutputPath': 's3://mastering-ml-aws/chapter4/sagemaker/output'},
#   'ResourceConfig': {'InstanceType': 'ml.c4.4xlarge',
#    'InstanceCount': 1,
#    'VolumeSizeInGB': 30},
#   'StoppingCondition': {'MaxRuntimeInSeconds': 360000},
#   'EnableNetworkIsolation': False,
#   'EnableInterContainerTrafficEncryption': False},
#  'HyperParameterTuningJobStatus': 'Completed',
#  'CreationTime': datetime.datetime(2019, 4, 7, 13, 42, 44, 162000, tzinfo=tzlocal()),
#  'HyperParameterTuningEndTime': datetime.datetime(2019, 4, 7, 13, 59, 8, 564000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2019, 4, 7, 13, 59, 8, 564000, tzinfo=tzlocal()),
#  'TrainingJobStatusCounters': {'Completed': 6,
#   'InProgress': 0,
#   'RetryableError': 0,
#   'NonRetryableError': 4,
#   'Stopped': 0},
#  'ObjectiveStatusCounters': {'Succeeded': 6, 'Pending': 0, 'Failed': 4},
#  'BestTrainingJob': {'TrainingJobName': 'xgboost-190407-1342-001-5c7e2a26',
#   'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:095585830284:training-job/xgboost-190407-1342-001-5c7e2a26',
#   'CreationTime': datetime.datetime(2019, 4, 7, 13, 42, 54, tzinfo=tzlocal()),
#   'TrainingStartTime': datetime.datetime(2019, 4, 7, 13, 45, 30, tzinfo=tzlocal()),
#   'TrainingEndTime': datetime.datetime(2019, 4, 7, 13, 48, 4, tzinfo=tzlocal()),
#   'TrainingJobStatus': 'Completed',
#   'TunedHyperParameters': {'eta': '0.4843166334129595',
#    'lambda': '892.5118136129357',
#    'max_depth': '7'},
#   'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'validation:auc',
#    'Value': 0.653240978717804},
#   'ObjectiveStatus': 'Succeeded'},
#  'ResponseMetadata': {'RequestId': '4d4437b5-8ab6-4f81-8856-bd197c5e1d72',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '4d4437b5-8ab6-4f81-8856-bd197c5e1d72',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4522',
#    'date': 'Sun, 07 Apr 2019 14:56:17 GMT'},
#   'RetryAttempts': 0}}
