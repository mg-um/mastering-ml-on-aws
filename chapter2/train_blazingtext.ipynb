# %%
import sagemaker
from sagemaker import get_execution_role
import json
import boto3

sess = sagemaker.Session()
role = get_execution_role()

bucket = "mastering-ml-aws"

prefix = "chapter2/blazingtext"

# %%
SRC_PATH = '/home/ec2-user/SageMaker/mastering-ml-on-aws/chapter2/'

with open(SRC_PATH + 'dem.txt', 'r') as file:
    dem_text = ["__label__0 " + line.strip('\n') for line in file]

with open(SRC_PATH + 'gop.txt', 'r') as file:
    gop_text = ["__label__1 " + line.strip('\n') for line in file]
    
corpus = dem_text + gop_text
    
from sklearn.model_selection import train_test_split
corpus_train, corpus_test = train_test_split(corpus, test_size=0.25, random_state=42)

# %%
corpus_train_txt = "\n".join(corpus_train)
corpus_test_txt = "\n".join(corpus_test)
with open('tweets.train', 'w') as file:
    file.write(corpus_train_txt)    
with open('tweets.test', 'w') as file:
    file.write(corpus_test_txt)

# %%
corpus_train_txt
# Out:
# '__label__1 “We are forever grateful for your service.” -@FLOTUS https://t.co/22vFTZguAQ\n__label__0 RT @CecileRichards: When your strategy relies on fewer people being able to vote, you’re on the wrong side of history. https://t.co/ncthe2W…\n__label__0 RT @AFLCIO: Scott Walker. Forever a national disgrace. #1u https://t.co/Hii42QMq3w\n__label__0 Democrats will hold this administration accountable for its attacks on human rights. #HumanRightsDay https://t.co/IGzOyzxzEi\n__label__0 RT @TomPerez: Congratulations to @CheriBustos on becoming the new chair of the @dccc. The Democratic Party is back, &amp; we\'re ready to build…\n__label__0 Donald Trump\'s temper tantrum could hurt the economy and force hundreds of thousands of federal employees to work without pay or be furloughed right before the holidays. The president will own any potential government shutdown. https://t.co/dYrbFLA9j9\n__label__0 RT @HealthCareGov: The recent federal court decision is still moving through the courts, and the exchanges are still open for business and…\n__label__0 RT @TomPerez: Woke up to the news that President George H.W. Bush has passed. His legacy is one of service and commitment to country — he w…\n__label__1 Remembering our 41st President— a true patriot whose service to our nation will never be forgotten.   https://t.co/mzw7txtsXk\n__label__1 A huge honor for senior adviser to the President, Jared Kushner.    Thanks to Kushner and the @realDonaldTrump administration, America is truly at a historic place in its relationship with Mexico!  https://t.co/uxJa5hGPpC\n__label__0 December 15 is almost here! Don\'t miss your chance to get health coverage during this open enrollment period. Head over to https://t.co/cUaYP7TbZj to get covered today. https://t.co/KdCJk5WNHv\n__label__1 .@senorrinhatch has served as a strong conservative leader in Congress for over 40 years.    RT to thank Senator Hatch for his commitment to public service and the conservative movement!  https://t.co/vXzF46ZBVN\n__label__1 “My administration will always stand with our cherished friend and partner, the state of Israel.” -@realDonaldTrump\n__label__1 “It is important for all Americans we get this done.” -@SteveScalise https://t.co/pxJqgMLZwq\n__label__1 RT @SecretService: It was an honor. https://t.co/Tjw9y4B0qo\n__label__0 RT @GovernorTomWolf: There’s still time to find a health care plan for next year. Open enrollment is ongoing through Saturday, December 15…\n__label__0 RT @HouseDemocrats: 8 in 10 people can #GetCovered for less than $75 per month. Check out what options are available for you and your famil…\n__label__1 "You have a responsibility to yourself, and also to those around you who may be struggling. And if you, or someone you know needs help, you need to be brave enough to ask, or strong enough to stand with them as they fight through the disease." -@FLOTUS #CrisisNextDoor\n__label__1 .@realDonaldTrump promised to make our communities safer—and he’s delivering on that promise.   Another promise kept. https://t.co/mxTVUQXNR7\n__label__1 “We are winning with China, not to mention the EU deal, the USMCA, and so many others.” -@kayleighmcenany https://t.co/cpOxCYeZag\n__label__0 🚨 Georgia: We\'ve got a runoff election for secretary of state and public service commissioner next week.   Let\'s go knock on some doors and dial those phones. Sign up for a shift here: https://t.co/17oEscjv9d. https://t.co/CWFFgiWWXy\n__label__0 Yes, it is! 👑 https://t.co/QChaP5RVNj\n__label__0 Hoy es su último día para inscribirse a un seguro médico.   Acceda a https://t.co/sukLSz0hle y consiga su plan de cuidado de salud hoy.\n__label__1 Polls are now OPEN in Georgia!  Find your polling location here ➡️ https://t.co/UgGVtgA4pM https://t.co/KYJJnFQ9kj\n__label__0 Amendment 4 was pretty straightforward. Ron DeSantis and Florida Republicans need to respect the will of the people. https://t.co/5r8egbm33Z\n__label__0 Trump promised autoworkers that they wouldn’t lose one plant if he was e ...

# %%
train_path = prefix + '/train'
validation_path = prefix + '/validation'

sess.upload_data(path='tweets.train', bucket=bucket, key_prefix=train_path)
sess.upload_data(path='tweets.test', bucket=bucket, key_prefix=validation_path)

s3_train_data = 's3://{}/{}'.format(bucket, train_path)
s3_validation_data = 's3://{}/{}'.format(bucket, validation_path)

# %%
container = sagemaker.amazon.amazon_estimator.get_image_uri('us-east-1', "blazingtext", "latest")

s3_output_location = 's3://{}/{}/output'.format(bucket, prefix)

# %%
bt_model = sagemaker.estimator.Estimator(container,
                                         role, 
                                         train_instance_count=1, 
                                         train_instance_type='ml.c4.4xlarge',
                                         train_volume_size = 30,
                                         train_max_run = 360000,
                                         input_mode= 'File',
                                         output_path=s3_output_location,
                                         sagemaker_session=sess)

# %%
bt_model.set_hyperparameters(mode="supervised",
                            epochs=10,
                            min_count=3,
                            learning_rate=0.05,
                            vector_dim=10,
                            early_stopping=False,
                            patience=5,
                            min_epochs=5,
                            word_ngrams=2)

train_data = sagemaker.session.s3_input(s3_train_data, distribution='FullyReplicated', 
                        content_type='text/plain', s3_data_type='S3Prefix')
validation_data = sagemaker.session.s3_input(s3_validation_data, distribution='FullyReplicated', 
                             content_type='text/plain', s3_data_type='S3Prefix')
data_channels = {'train': train_data, 'validation': validation_data}

# %%
bt_model.fit(inputs=data_channels, logs=True)
# Out:
# INFO:sagemaker:Creating training-job with name: blazingtext-2018-12-22-15-40-41-862
# 2018-12-22 15:40:42 Starting - Starting the training job...
# 2018-12-22 15:40:43 Starting - Launching requested ML instances......
# 2018-12-22 15:41:46 Starting - Preparing the instances for training...
# 2018-12-22 15:42:42 Downloading - Downloading input data..
# Arguments: train
# [12/22/2018 15:42:49 WARNING 139992524269376] Loggers have already been setup.
# [12/22/2018 15:42:49 WARNING 139992524269376] Loggers have already been setup.
# [12/22/2018 15:42:49 INFO 139992524269376] nvidia-smi took: 0.0251660346985 secs to identify 0 gpus
# [12/22/2018 15:42:49 INFO 139992524269376] Running single machine CPU BlazingText training using supervised mode.
# [12/22/2018 15:42:49 INFO 139992524269376] Processing /opt/ml/input/data/train/tweets.train . File size: 0 MB
# [12/22/2018 15:42:49 INFO 139992524269376] Processing /opt/ml/input/data/validation/tweets.test . File size: 0 MB
# Read 0M words
# Number of words:  407
# ##### Alpha: -0.0003  Progress: 100.54%  Million Words/sec: 0.72 #####
# ##### Alpha: 0.0000  Progress: 100.00%  Million Words/sec: 0.72 #####
#
# Training finished.
# Average throughput in Million words/sec: 0.72
# Total training time in seconds: 0.10
#
# #train_accuracy: 0.6433
# Number of train examples: 300
#
# #validation_accuracy: 0.61
# Number of validation examples: 100
#
# 2018-12-22 15:42:59 Training - Training image download completed. Training in progress.
# 2018-12-22 15:42:59 Uploading - Uploading generated training model
# 2018-12-22 15:43:16 Completed - Training job completed
# Billable seconds: 35

# %%
bt_model

# %%
# Out:
# 'model'

# %%
transformer = bt_model.transformer(instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: blazingtext-2018-12-22-14-51-28-246
# WARNING:sagemaker:Using already existing model: blazingtext-2018-12-22-14-51-28-246

# %%
transformer.transform('s3://mastering-ml-aws/chapter2/blazingtext/validation/')
# Out:
# INFO:sagemaker:Creating transform job with name: blazingtext-2018-12-22-15-08-35-039

# %%
transformer.wait()

# %%
predictor = bt_model.deploy(initial_instance_count = 1,instance_type = 'ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: blazingtext-2018-12-22-15-44-01-592
# INFO:sagemaker:Creating endpoint with name blazingtext-2018-12-22-15-40-41-862
# ---------------------------------------------------------------------------!

# %%
# !aws s3 ls --recursive s3://mastering-ml-aws/chapter2/blazingtext

# %%
corpus_test_no_labels = [x[11:] for x in corpus_test]

payload = {"instances" : corpus_test_no_labels}

response = predictor.predict(json.dumps(payload))

predictions = json.loads(response)
print(json.dumps(predictions, indent=2))
# Out:
# [
#   {
#     "prob": [
#       0.5003929734230042
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.500934362411499
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5003452301025391
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5022704601287842
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5004196763038635
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5000465512275696
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5001659989356995
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5006721019744873
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5006396770477295
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5001750588417053
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5005156397819519
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5000677704811096
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5007967948913574
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5000414848327637
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5003377795219421
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.500151515007019
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5007360577583313
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5007867813110352
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5008065104484558
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5005864500999451
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5002189874649048
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5000504851341248
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5009070038795471
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5014070272445679
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.500108003616333
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.500673234462738
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5008955001831055
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5001512169837952
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001122951507568
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5002203583717346
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.500278651714325
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5004359483718872
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5006998181343079
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5012744069099426
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001426339149475
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5004568099975586
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5007264614105225
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5010820031166077
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.50080406665802
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5004674792289734
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5002642869949341
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5005900859832764
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5000607371330261
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.500310480594635
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.501531720161438
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5003447532653809
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5009533166885376
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5002517700195312
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001547336578369
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001808404922485
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.501335859298706
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5007041096687317
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5007426142692566
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5000962615013123
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5006809234619141
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5006875991821289
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5007414817810059
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5002597570419312
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5008684992790222
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5020846128463745
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5001091957092285
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5002661943435669
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.500664234161377
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5006147623062134
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5005722641944885
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5007129311561584
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5006063580513
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001958012580872
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5003380179405212
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001713037490845
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5007387399673462
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5011422038078308
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5004082918167114
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5009593963623047
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001534819602966
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5004254579544067
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001845955848694
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5003029108047485
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001295804977417
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5013402700424194
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5006004571914673
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5003545880317688
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5006288290023804
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5005951523780823
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5008060932159424
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5004683136940002
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5008022785186768
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5000846982002258
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5002403259277344
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5005330443382263
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5006654262542725
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5000653862953186
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.500346839427948
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5001217126846313
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5001224279403687
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5002315640449524
#     ],
#     "label": [
#       "__label__0"
#     ]
#   },
#   {
#     "prob": [
#       0.5002812147140503
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5006946325302124
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5009498000144958
#     ],
#     "label": [
#       "__label__1"
#     ]
#   },
#   {
#     "prob": [
#       0.5000826716423035
#     ],
#     "label": [
#       "__label__1"
#     ]
#   }
# ]

# %%
predicted_labels = [prediction['label'][0] for prediction in predictions]

# %%
predicted_labels[:4]
# Out:
# ['__label__0', '__label__1', '__label__0', '__label__0']

# %%
actual_labels = [x[:10] for x in corpus_test]
actual_labels[:4]
# Out:
# ['__label__1', '__label__1', '__label__0', '__label__1']

# %%
matches = [(actual_label == predicted_label) for (actual_label, predicted_label) in zip(actual_labels, predicted_labels)]
matches[:4]
# Out:
# [False, True, True, False]

# %%
matches.count(True) / len(matches)
# Out:
# 0.61
